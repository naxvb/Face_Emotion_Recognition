# %%
import os 
import cv2

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Natalia\\sortech'

# %%
parent = 'C:\\Users\\Natalia\\sortech\custom_dataset\\'

# %%
os.chdir(parent)

i=0
for folder in os.listdir(parent):
    path = parent + folder + ("\\")
    i =0
    for filename in os.listdir(path):
        print(path + filename)
        read = cv2. imread(path + filename)
        gray = cv2.cvtColor(read, cv2.COLOR_BGR2GRAY)
        cv2. imwrite(path+filename,gray)
print(i)
# Out:
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 120713.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 120749.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 120819.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 120838.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 121926.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 122014.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 122034.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 132240.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 132257.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 133205.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 133222.png
# C:\Users\Natalia\sortech\custom_dataset\angry\Zrzut ekranu 2022-12-01 133234.png
# ...
